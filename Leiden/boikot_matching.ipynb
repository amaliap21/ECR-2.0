# %% [markdown]
# # NEW TOTAL DATA VAKSIN

# %%
import pandas as pd

df_indobert = pd.read_csv("boikot_checkpoint_gpt54_sentiment.csv", low_memory=False)
df_indobert.shape
# Out:
# (10000, 23)

# %%
df_indobert = df_indobert[["cleaned_text", "indobert_label"]].drop_duplicates()
df_indobert.head()
# Out:
#                                         cleaned_text indobert_label
# 0  Ehh gendut, bangsat emang ye, menlu sebelumnya...       negative
# 1  Boikot Deddy! Manipulasi Citra, Legitimasi, da...       negative
# 2  Ayo boikot kita hanya bisa membantu dengan tdk...       negative
# 3  𝙼𝙰𝚁𝚅𝙴𝙻 telah mendukung Israel secara finansial...        neutral
# 4  carat lu mending BELAJAR dah dr svtrh kmrn sam...       negative

# %%
df_new = pd.read_csv("total_data_cleaned_mcd.csv", low_memory=False)

df_new.shape
# Out:
# (515135, 54)

# %%
df_new = df_new[["cleaned_text", "final_sentiment"]].drop_duplicates()
df_new.head()
# Out:
#                                         cleaned_text final_sentiment
# 0  Kegiatan dan konferensi pers dari istana tidak...         neutral
# 1                                IYAYA raLat kk wowo         neutral
# 2  Netanyahu bermuka tebal, syok sendiri berucap ...         neutral
# 3           Tuak beer ibadah hiji selama bbrpa tahun         neutral
# 4  JIKA ANDA SETANYAHU YAHUDI BERANI AMBIL SIKAP ...        negative

# %%
# join the two dataframes on the "cleaned_text" column, keep final_sentiment from new dataframe and indobert_label from indobert dataframe
df_joined = pd.merge(
    pd.DataFrame({"cleaned_text": df_indobert["cleaned_text"], "indobert_label": df_indobert["indobert_label"]}),
    pd.DataFrame({"cleaned_text": df_new["cleaned_text"], "final_sentiment": df_new["final_sentiment"]}),
    on="cleaned_text",
    how="inner",
).drop_duplicates()
df_joined.head()
# Out:
#                                         cleaned_text indobert_label  \
# 0  Ehh gendut, bangsat emang ye, menlu sebelumnya...       negative
# 1  Boikot Deddy! Manipulasi Citra, Legitimasi, da...       negative
# 2  Ayo boikot kita hanya bisa membantu dengan tdk...       negative
# 3  𝙼𝙰𝚁𝚅𝙴𝙻 telah mendukung Israel secara finansial...        neutral
# 4  carat lu mending BELAJAR dah dr svtrh kmrn sam...       negative
#
#   final_sentiment
# 0        negative
# 1         neutral
# 2        negative
# 3         neutral
# 4        negative

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Pakai dataframe hasil join sebagai sampel evaluasi
df_sample = df_joined.copy()
df = df_sample

# Tentukan kolom teks
text_col = None
for candidate in ['cleaned_text', 'full_text', 'text', 'content', 'tweet']:
    if candidate in df_sample.columns:
        text_col = candidate
        break

# 3.5c. Evaluasi semua metode sentimen + Confusion matrices + F1 bar chart

if text_col is not None:
    ref = df_sample['final_sentiment'].astype(str).str.lower()
    _label_norm = {'pro': 'positive', 'pos': 'positive',
                   'contra': 'negative', 'neg': 'negative', 'neu': 'neutral'}
    ref = ref.map(lambda x: _label_norm.get(x, x))
    labels_order = ['negative', 'neutral', 'positive']

    method_cols = {
        'IndoBERT': 'indobert_label',
    }
    predictions = {name: df_sample[col]
                   for name, col in method_cols.items() if col in df_sample.columns}

    missing_methods = [name for name, col in method_cols.items()
                       if col not in df_sample.columns]
    if missing_methods:
        print(f"Metode tidak tersedia (dilewati): {missing_methods}")

    if len(predictions) == 0:
        print("Tidak ada kolom prediksi sentimen. Evaluasi dilewati.")
    else:
        from sklearn.metrics import (accuracy_score, f1_score, precision_score,
                                     recall_score, confusion_matrix)

        eval_rows = []
        conf_matrices = {}
        for name, preds in predictions.items():
            pred = preds.astype(str).str.lower().map(lambda x: _label_norm.get(x, x))
            acc = accuracy_score(ref, pred)
            f1_mac = f1_score(ref, pred, labels=labels_order, average='macro', zero_division=0)
            f1_per = f1_score(ref, pred, labels=labels_order, average=None, zero_division=0)
            prec = precision_score(ref, pred, labels=labels_order, average='macro', zero_division=0)
            rec = recall_score(ref, pred, labels=labels_order, average='macro', zero_division=0)
            cm = confusion_matrix(ref, pred, labels=labels_order)
            eval_rows.append({'Method': name, 'Accuracy': acc, 'Macro-F1': f1_mac,
                              'F1 Neg': f1_per[0], 'F1 Neu': f1_per[1], 'F1 Pos': f1_per[2],
                              'Precision': prec, 'Recall': rec})
            conf_matrices[name] = cm

        df_eval = pd.DataFrame(eval_rows)
        print("=== PERBANDINGAN METODE SENTIMENT ===")
        print(df_eval.to_string(index=False))

        # Confusion matrices
        n_methods = len(conf_matrices)
        ncols = min(3, n_methods)
        nrows = math.ceil(n_methods / ncols)
        fig, axes = plt.subplots(nrows, ncols, figsize=(7 * ncols, 6 * nrows))
        if n_methods == 1:
            axes = np.array([axes])

        for ax, (name, cm) in zip(np.array(axes).flat, conf_matrices.items()):
            sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax,
                        xticklabels=labels_order, yticklabels=labels_order)
            acc_v = accuracy_score(ref, predictions[name].astype(str).str.lower()
                                   .map(lambda x: _label_norm.get(x, x)))
            ax.set_title(f'{name}\nAccuracy={acc_v:.3f}', fontweight='bold')
            ax.set_xlabel('Predicted')
            ax.set_ylabel('True')

        for ax in list(np.array(axes).flat)[len(conf_matrices):]:
            ax.axis('off')

        plt.suptitle('Confusion Matrices - Perbandingan Metode Sentiment',
                     fontweight='bold', fontsize=14, y=1.02)
        plt.tight_layout()
        plt.show()

        # F1 bar chart
        fig, ax = plt.subplots(figsize=(max(10, 4 * len(df_eval)), 5))
        x = np.arange(len(df_eval))
        width = 0.2
        ax.bar(x - 1.5 * width, df_eval['F1 Neg'], width, label='F1 Negative', color='#e74c3c', alpha=0.8)
        ax.bar(x - 0.5 * width, df_eval['F1 Neu'], width, label='F1 Neutral', color='#95a5a6', alpha=0.8)
        ax.bar(x + 0.5 * width, df_eval['F1 Pos'], width, label='F1 Positive', color='#2ecc71', alpha=0.8)
        ax.bar(x + 1.5 * width, df_eval['Macro-F1'], width, label='Macro-F1', color='#3498db', alpha=0.8)
        ax.set_xticks(x)
        ax.set_xticklabels(df_eval['Method'], rotation=20, ha='right')
        ax.set_ylabel('F1 Score')
        ax.set_title('Sentiment Methods - F1 Score Comparison', fontweight='bold')
        ax.legend()
        ax.grid(True, alpha=0.3, axis='y')
        ax.set_ylim(0, 1)
        plt.tight_layout()
        plt.show()
else:
    print("Evaluasi sentimen dilewati (kolom teks tidak ditemukan).")
# Out:
# === PERBANDINGAN METODE SENTIMENT ===
#   Method  Accuracy  Macro-F1   F1 Neg   F1 Neu   F1 Pos  Precision  Recall
# IndoBERT  0.632911  0.517803 0.743659 0.443792 0.365957   0.516232 0.57034

# %%
# Ambil sample 10 data per sel error (off-diagonal) confusion matrix
import pandas as pd

labels_order = ['negative', 'neutral', 'positive']
_label_norm = {
    'pro': 'positive', 'pos': 'positive',
    'contra': 'negative', 'neg': 'negative', 'neu': 'neutral'
}

# Pastikan dataframe sumber ada
if 'df_joined' not in globals():
    raise ValueError("`df_joined` tidak ditemukan. Jalankan cell join dataframe terlebih dahulu.")

# Siapkan dataframe kerja
df_err = df_joined[['cleaned_text', 'indobert_label', 'final_sentiment']].copy()
df_err['indobert_label'] = df_err['indobert_label'].astype(str).str.lower().map(lambda x: _label_norm.get(x, x))
df_err['final_sentiment'] = df_err['final_sentiment'].astype(str).str.lower().map(lambda x: _label_norm.get(x, x))

# Filter hanya label yang valid
df_err = df_err[
    df_err['indobert_label'].isin(labels_order)
    & df_err['final_sentiment'].isin(labels_order)
]

# Ambil 10 sample untuk tiap pasangan true-pred yang salah (6 sel off-diagonal)
samples_per_error_cell = {}
sample_rows = []

for true_label in labels_order:
    for pred_label in labels_order:
        if true_label == pred_label:
            continue  # skip diagonal (prediksi benar)

        key = f"true={true_label} | pred={pred_label}"
        subset = df_err[
            (df_err['final_sentiment'] == true_label)
            & (df_err['indobert_label'] == pred_label)
        ][['cleaned_text', 'indobert_label', 'final_sentiment']]

        n_take = min(10, len(subset))
        sampled = subset.sample(n=n_take, random_state=42) if n_take > 0 else subset.copy()
        samples_per_error_cell[key] = sampled

        if n_take > 0:
            temp = sampled.copy()
            temp['cm_cell'] = key
            sample_rows.append(temp)

# Gabungkan semua sample agar mudah dilihat / diekspor
if sample_rows:
    df_error_samples = pd.concat(sample_rows, ignore_index=True)
    df_error_samples = df_error_samples[['cm_cell', 'cleaned_text', 'indobert_label', 'final_sentiment']]
else:
    df_error_samples = pd.DataFrame(columns=['cm_cell', 'cleaned_text', 'indobert_label', 'final_sentiment'])

print("Jumlah sample per cell error:")
for k, v in samples_per_error_cell.items():
    print(f"- {k}: {len(v)}")

print("\nPreview gabungan sample:")
df_error_samples.head(20)
# Out:
# Jumlah sample per cell error:
# - true=negative | pred=neutral: 10
# - true=negative | pred=positive: 10
# - true=neutral | pred=negative: 10
# - true=neutral | pred=positive: 10
# - true=positive | pred=negative: 10
# - true=positive | pred=neutral: 10
#
# Preview gabungan sample:
#                           cm_cell  \
# 0    true=negative | pred=neutral
# 1    true=negative | pred=neutral
# 2    true=negative | pred=neutral
# 3    true=negative | pred=neutral
# 4    true=negative | pred=neutral
# 5    true=negative | pred=neutral
# 6    true=negative | pred=neutral
# 7    true=negative | pred=neutral
# 8    true=negative | pred=neutral
# 9    true=negative | pred=neutral
# 10  true=negative | pred=positive
# 11  true=negative | pred=positive
# 12  true=negative | pred=positive
# 13  true=negative | pred=positive
# 14  true=negative | pred=positive
# 15  true=negative | pred=positive
# 16  true=negative | pred=positive
# 17  true=negative | pred=positive
# 18  true=negative | pred=positive
# 19  true=negative | pred=positive
#
#                                          cleaned_text indobert_label  \
# 0   Harus ada tindakan yg lebih untuk paling tidak...        neutral
# 1   Call me lebay, tp semoga aku tetapi konsisten ...        neutral
# 2                              Boikot aja lah filmnya        neutral
# 3            Kami Masih Konsisten Boikot, Kalau Anda?        neutral
# 4   Dunia Bersatu Melawan Israel? Sanksi, Boikot, ...        neutral
# 5        Statistik terus bertambah. Teruskan boikot !        neutral
# 6   महाकुंभ प्रयागराज प्रयागराज अयोध्या धाम चलो अय...        neutral
# 7   tapi banyak hal yg menguatkan kenapa seharusny...        neutral
# 8      Aneeehhh....tu monyt solo yg hrs nya di boikot        neutral
# 9   2. Dengan boikot, penggemar dapat menunjukkan ...        neutral
# 10  yang tak boikot/post lansung pasal palestine n...       positive
# 11  Nambah fun fact, AW yang ini ga perlu diboikot...       positive
# 12  tayang indo dicgv dan cinepolis. boycot urusan...       positive
# 13  Setidaknya liganya hidup dengan animo penyokon...       positive
# 14  Akhirnya nemuin ayam spicy yang rasanya ga kal...       positive
# 15  dia sengaja post kat ep last. drama tu dah mem...       positive
# 16                             Boikot Israel Jahanam        positive
# 17  udah ga sedih ga bisa mam ayam sebelah yg boik...       positive
# 18  Wota banget sih, banyak kaos yg desainnya bagu...       positive
# 19  Guys aku tahu bagus banget. Tapi inget boikot ...       positive
#
#    final_sentiment
# 0         negative
# 1         negative
# 2         negative
# 3         negative
# 4         negative
# 5         negative
# 6         negative
# 7         negative
# 8         negative
# 9         negative
# 10        negative
# 11        negative
# 12        negative
# 13        negative
# 14        negative
# 15        negative
# 16        negative
# 17        negative
# 18        negative
# 19        negative

# %%
# 1) Simpan sample ke file baru + 2) tambah kolom kosong manual_label + 3) labeling interaktif
import os
import pandas as pd

if 'df_error_samples' not in globals():
    raise ValueError("`df_error_samples` belum ada. Jalankan cell sampling error terlebih dahulu.")

base_cols = ['cm_cell', 'cleaned_text', 'indobert_label', 'final_sentiment']
missing_cols = [c for c in base_cols if c not in df_error_samples.columns]
if missing_cols:
    raise ValueError(f"Kolom berikut belum ada di df_error_samples: {missing_cols}")

# File awal untuk proses labeling
samples_file = 'error_samples_for_labeling.csv'
labeled_file = 'error_samples_labeled.csv'

df_to_label = df_error_samples[base_cols].copy()
if 'manual_label' not in df_to_label.columns:
    df_to_label['manual_label'] = ''

# Simpan file sample baru (dengan manual_label kosong)
df_to_label.to_csv(samples_file, index=False, encoding='utf-8-sig')
print(f"File sample tersimpan: {samples_file} ({len(df_to_label)} baris)")

# Jika sudah pernah ada file labeled, lanjutkan dari file itu agar tidak mengulang dari awal
if os.path.exists(labeled_file):
    prev = pd.read_csv(labeled_file, dtype=str).fillna('')
    required = base_cols + ['manual_label']
    if all(c in prev.columns for c in required):
        df_work = prev[required].copy()
        print(f"Lanjut dari file existing: {labeled_file}")
    else:
        df_work = df_to_label[required].copy()
        print("Struktur file labeled lama tidak cocok, mulai dari sample terbaru.")
else:
    df_work = df_to_label[base_cols + ['manual_label']].copy()

valid_labels = {'positive', 'negative', 'neutral'}

print("\nMulai labeling manual.")
print("Input yang diterima: positive / negative / neutral")
print("Ketik 'skip' untuk lewati, 'exit' untuk berhenti lebih awal.\n")

for i in range(len(df_work)):
    current = str(df_work.at[i, 'manual_label']).strip().lower()
    if current in valid_labels:
        continue  # sudah terisi valid, lewati

    print("=" * 80)
    print(f"Data ke-{i+1}/{len(df_work)}")
    print(f"cm_cell         : {df_work.at[i, 'cm_cell']}")
    print(f"indobert_label       : {df_work.at[i, 'indobert_label']}")
    print(f"final_sentiment : {df_work.at[i, 'final_sentiment']}")
    print(f"cleaned_text    : {df_work.at[i, 'cleaned_text']}")

    while True:
        user_in = input("manual_label [positive/negative/neutral | skip | exit]: ").strip().lower()
        if user_in in valid_labels:
            df_work.at[i, 'manual_label'] = user_in
            break
        if user_in == 'skip':
            break
        if user_in == 'exit':
            print("Proses dihentikan oleh user.")
            df_work.to_csv(labeled_file, index=False, encoding='utf-8-sig')
            print(f"Progress tersimpan ke: {labeled_file}")
            raise SystemExit
        print("Input tidak valid. Gunakan: positive, negative, neutral, skip, atau exit.")

# Simpan hasil akhir
df_work.to_csv(labeled_file, index=False, encoding='utf-8-sig')
print(f"\nSelesai. Hasil tersimpan ke: {labeled_file}")
print("Kolom output: cm_cell, cleaned_text, indobert_label, final_sentiment, manual_label")

# Preview hasil
df_work.head(10)
# Out:
# File sample tersimpan: error_samples_for_labeling.csv (60 baris)
#
# Mulai labeling manual.
# Input yang diterima: positive / negative / neutral
# Ketik 'skip' untuk lewati, 'exit' untuk berhenti lebih awal.
#
# ================================================================================
# Data ke-1/60
# cm_cell         : true=negative | pred=neutral
# indobert_label       : neutral
# final_sentiment : negative
# cleaned_text    : Harus ada tindakan yg lebih untuk paling tidak sebagai federasi dunia harusnya bisa ambil sikap atas apa yg terjadi antara israel dan palestina. Boikot produk fifa juga menjadi hal yg harus dilakukam jika fifa sendiri tidak melakukan tindakan tegas.
# ================================================================================
# Data ke-2/60
# cm_cell         : true=negative | pred=neutral
# indobert_label       : neutral
# final_sentiment : negative
# cleaned_text    : Call me lebay, tp semoga aku tetapi konsisten boikot produk yg terafiliasi isr4el ~
# ================================================================================
# Data ke-3/60
# cm_cell         : true=negative | pred=neutral
# indobert_label       : neutral
# final_sentiment : negative
# cleaned_text    : Boikot aja lah filmnya
# ================================================================================
# Data ke-4/60
# cm_cell         : true=negative | pred=neutral
# indobert_label       : neutral
# final_sentiment : negative
# cleaned_text    : Kami Masih Konsisten Boikot, Kalau Anda?
# ================================================================================
# Data ke-5/60
# cm_cell         : true=negative | pred=neutral
# indobert_label       : neutral
# final_sentiment : negative
# cleaned_text    : Dunia Bersatu Melawan Israel? Sanksi, Boikot, dan Isolasi Global Semakin Membesar Israel kini menghadapi isolasi internasional terbesar sepanjang sejarah modernnya. Dari Eropa hingga Timur Tengah, dari panggung diplomatik hingga ajang budaya dan olahraga, tekanan terhadap Tel Aviv semakin membesar. Belgia, Spanyol, dan Norwegia telah memimpin sanksi ekonomi, embargo senjata, hingga boikot diplomatik. Uni Eropa bahkan mempertimbangkan langkah yang lebih keras. Sementara itu, dunia seni dan olahraga mulai menolak ke
60
# cm_cell         : true=negative | pred=positive
# indobert_label       : positive
# final_sentiment : negative
# cleaned_text    : Boikot Israel Jahanam
# ================================================================================
# Data ke-18/60
# cm_cell         : true=negative | pred=positive
# indobert_label       : positive
# final_sentiment : negative
# cleaned_text    : udah ga sedih ga bisa mam ayam sebelah yg boikot karena ini udah ENAK BGT + murah ada yg pedes juga tau guyss, mungkin next aku mau cobaa. nihh yaa kalian kalo ngiler langsung coba juga
# ================================================================================
# Data ke-19/60
# cm_cell         : true=negative | pred=positive
# indobert_label       : positive
# final_sentiment : negative
# cleaned_text    : Wota banget sih, banyak kaos yg desainnya bagus hei, boikat boikot tai ledig kalo kaya gini semua
# ================================================================================
# Data ke-20/60
# cm_cell         : true=negative | pred=positive
# indobert_label       : positive
# final_sentiment : negative
# cleaned_text    : Guys aku tahu bagus banget. Tapi inget boikot ya kawan2...
# ================================================================================
# Data ke-21/60
# cm_cell         : true=neutral | pred=negative
# indobert_label       : negative
# final_sentiment : neutral
# cleaned_text    : Omar makin turun banget tbl tbl  Ni yang kemaren boikot" gue tabok lu ya
# ================================================================================
# Data ke-22/60
# cm_cell         : true=neutral | pred=negative
# indobert_label       : negative
# final_sentiment : neutral
# cleaned_text    : sejak boikot, aku ngga makan mekdi emang.
# ================================================================================
# Data ke-23/60
# cm_cell         : true=neutral | pred=negative
# indobert_label       : negative
# final_sentiment : neutral
# cleaned_text    : knp gk boikot produk2 yahudi spt monoteisme, narasi kitab, nabi2, sunat, halal, hijab, dst?
# ================================================================================
# Data ke-24/60
# cm_cell         : true=neutral | pred=negative
# indobert_label       : negative
# final_sentiment : neutral
# cleaned_text    : dariawal kan kalian emg gk setuju ini dijadiin la, coba lu baca hbs tweet gue deh. nah klu kalian gk pd mau nonton dan boikot ini film, trs siapa lg yg jadi targetnya kak klu bkn fans kdrama?
# ================================================================================
# Data ke-25/60
# cm_cell         : true=neutral | pred=negative
# indobert_label       : negative
# final_sentiment : neutral
# cleaned_text    : eh kok ada sih jeros yg misuh² karena jeros lain pada boycot bp2 dan bilang kalo "namanya juga survival show, wajar kayak gitu" nih yah lemme explain why zerose boycot bp2. first of all, acara ini tuh dari awal selalu bawa² nama jebis, apalagi mereka pake title "the next zb1"—
# ================================================================================
# Data ke-26/60
# cm_cell         : true=neutral | pred=negative
# indobert_label       : negative
# final_sentiment : neutral
# cleaned_text    : Kurang jauh main lu bnyk tyf yg solo stan  santai aja kak paling besok udah balik lagi fans si Mark di tiktok udh bnyk tuh yg ga tega marah sama Mark sambil nangis nangis pki bg lagu sedih wkwkwk emang boikot KPop itu hanya buat gaya gayaan doang
# ================================================================================
# Data ke-27/60
# cm_cell         : true=neutral | pred=negative
# indobert_label       : negative
# final_sentiment : neutral
# cleaned_text    : boikot aja. tinggal rating 1 di apps store
# ================================================================================
# Data ke-28/60
# cm_cell         : true=neutral | pred=negative
# indobert_label       : negative
# final_sentiment : neutral
# cleaned_text    : Kalo tanggepan kalian gini, malah jadi sama aja dong kek yg dilakuin army difoto itu. Kalian bilang army standar ganda soal t yg jadi ba cc, sedangkan kalian juga belain j pas gue call out dia jadi ba adidas... jadi gimana nih, ini boikot atas dasar apa sih sebenernya???
# ================================================================================
# Data ke-29/60
# cm_cell         : true=neutral | pred=negative
# indobert_label       : negative
# final_sentiment : neutral
# cleaned_text    : Kan disini ada terimakasih aunty Melani  kalo di sokor kaya gitu mah bisa berabe, promotor, agensi Ama artis a bisa bener-bener mereka boikot+ rujak
# ================================================================================
# Data ke-30/60
# cm_cell         : true=neutral | pred=negative
# indobert_label       : negative
# final_sentiment : neutral
# cleaned_text    : TERKINI Kesatuan Sekerja Syarikat Minyak terbesar di Brazil mendesak agar Presiden Brazil, Lula Inacio melaksanakan boikot penjualan minyak kepada Israel sebagai tanda solidariti kepada Gaza dan menentang kekejaman Israel
# ================================================================================
# Data ke-31/60
# cm_cell         : true=neutral | pred=positive
# indobert_label       : positive
# final_sentiment : neutral
# cleaned_text    : Neozen Memanggil seluruh alumni boikot akbar taun 2024 memanggil seluruh yg suka naikin HT tanpa lirik kanan/kiri fokus mengedukasi bukan melenceng sana sini, kita buktikan bahwa kita sangat solid jangan biarkan kita terpecah belah lagi
# ================================================================================
# Data ke-32/60
# cm_cell         : true=neutral | pred=positive
# indobert_label       : positive
# final_sentiment : neutral
# cleaned_text    
60
# cm_cell         : true=positive | pred=neutral
# indobert_label       : neutral
# final_sentiment : positive
# cleaned_text    : Gerakan boikot produk Tesla di Amerika Serikat masih berlanjut dan baru-baru ini penolakan atas produk milik Elon Musk tersebut muncul di California. Pergerakan ini mulai mempengaruhi perusahaan dengan dampak nyata reputasi dan basis pelanggannya bahkan kekayaan bersih Musk menurun sebesar USD29 miliar pada pekan pertama Maret 2025. Berita selengkapnya klik di sini: Stasiun televisi ini pertama kali siaran pada tanggal 29 September 2010 hingga saat ini. IDX Channel memiliki tagline Your Trustworthy Economic, Business and Capital Market Channel. Saluran televisi ini bermarkas di Gedung Bursa Efek Indonesia Tower 2, Lantai 1, Jalan Jenderal Sudirman Kav. 52-53, Jakarta Selatan. Saksikan terus IDX Channel IndiHome Channel 119 Indovision Channel 100 K-Vision Channel 129 First Media Channel 389 Oxygen Channel 137 -------------------------------------------- Follow US on Social Media Website - Instagram - Facebook - Twitter - ------------------------------------------ Download Aplikasi IDX Channel Andorid - iOS - ------------------------------------------ Program dan News Anchor IDX CHANNEL Market Buzz (Senin – Jumat 08.30-09.30) Wicky Adrian (IG : ) Prisa Sombo Datu ( IG : ) IDX 1st Session Closing (Senin – Jumat 11.30-12.30) Fajar Wayong (IG : .wayong) IDX 2nd Session Closing (Senin – Jumat 15.30-16.30) Deffid San Opel (IG : ) Market Review (Senin – Jumat 21.00-22.00) Prasetyo Wibowo (IG : ) Prime Market Highlight (Senin - Jumat 20.00-21.00) Rosaline Hioe (IG : ) & Fajar Wayong (IG : .wayong)
# ================================================================================
# Data ke-57/60
# cm_cell         : true=positive | pred=neutral
# indobert_label       : neutral
# final_sentiment : positive
# cleaned_text    : Alhamdulillah kami sudah memboikot nestle dan mondelez secara natural tanpa seruan boikot dari pihak manapun.
# ================================================================================
# Data ke-58/60
# cm_cell         : true=positive | pred=neutral
# indobert_label       : neutral
# final_sentiment : positive
# cleaned_text    : Orang kata Zus berjaya sebab orang boikot starbucks tapi orang tak perasan yang cafe lain pun ada banyak tapi tak berjaya macam Zus. Zus berjaya sebab sistem dia efektif dan efisien, boikot itu hanya catalyzer.
# ================================================================================
# Data ke-59/60
# cm_cell         : true=positive | pred=neutral
# indobert_label       : neutral
# final_sentiment : positive
# cleaned_text    : Mantap jomalone gue pake lo lagi, kalau engga gue akan boikot lo yaaa
# ================================================================================
# Data ke-60/60
# cm_cell         : true=positive | pred=neutral
# indobert_label       : neutral
# final_sentiment : positive
# cleaned_text    : Dulu kita kompak boikot bisnis yg terafiliasi dgn zionis israel, sekarang saatnya Boikot semua bisnis zionis coklat dan zionis ijo, sebagian dari mereka pasti ada bisnis
#
# Selesai. Hasil tersimpan ke: error_samples_labeled.csv
# Kolom output: cm_cell, cleaned_text, indobert_label, final_sentiment, manual_label
#                         cm_cell  \
# 0  true=negative | pred=neutral
# 1  true=negative | pred=neutral
# 2  true=negative | pred=neutral
# 3  true=negative | pred=neutral
# 4  true=negative | pred=neutral
# 5  true=negative | pred=neutral
# 6  true=negative | pred=neutral
# 7  true=negative | pred=neutral
# 8  true=negative | pred=neutral
# 9  true=negative | pred=neutral
#
#                                         cleaned_text indobert_label  \
# 0  Harus ada tindakan yg lebih untuk paling tidak...        neutral
# 1  Call me lebay, tp semoga aku tetapi konsisten ...        neutral
# 2                             Boikot aja lah filmnya        neutral
# 3           Kami Masih Konsisten Boikot, Kalau Anda?        neutral
# 4  Dunia Bersatu Melawan Israel? Sanksi, Boikot, ...        neutral
# 5       Statistik terus bertambah. Teruskan boikot !        neutral
# 6  महाकुंभ प्रयागराज प्रयागराज अयोध्या धाम चलो अय...        neutral
# 7  tapi banyak hal yg menguatkan kenapa seharusny...        neutral
# 8     Aneeehhh....tu monyt solo yg hrs nya di boikot        neutral
# 9  2. Dengan boikot, penggemar dapat menunjukkan ...        neutral
#
#   final_sentiment manual_label
# 0        negative     negative
# 1        negative     negative
# 2        negative     negative
# 3        negative     negative
# 4        negative     negative
# 5        negative     negative
# 6        negative      neutral
# 7        negative      neutral
# 8        negative     negative
# 9        negative     negative

# %%
# 1) Simpan sample ke file baru + 2) tambah kolom kosong manual_label + 3) labeling interaktif
import os
import pandas as pd

if 'df_error_samples' not in globals():
    raise ValueError("`df_error_samples` belum ada. Jalankan cell sampling error terlebih dahulu.")

base_cols = ['cm_cell', 'cleaned_text', 'indobert_label', 'final_sentiment']
missing_cols = [c for c in base_cols if c not in df_error_samples.columns]
if missing_cols:
    raise ValueError(f"Kolom berikut belum ada di df_error_samples: {missing_cols}")

# File awal untuk proses labeling
samples_file = 'error_samples_for_labeling.csv'
labeled_file = 'error_samples_labeled.csv'

df_to_label = df_error_samples[base_cols].copy()
if 'manual_label' not in df_to_label.columns:
    df_to_label['manual_label'] = ''

# Simpan file sample baru (dengan manual_label kosong)
df_to_label.to_csv(samples_file, index=False, encoding='utf-8-sig')
print(f"File sample tersimpan: {samples_file} ({len(df_to_label)} baris)")

# Jika sudah pernah ada file labeled, lanjutkan dari file itu agar tidak mengulang dari awal
if os.path.exists(labeled_file):
    prev = pd.read_csv(labeled_file, dtype=str).fillna('')
    required = base_cols + ['manual_label']
    if all(c in prev.columns for c in required):
        df_work = prev[required].copy()
        print(f"Lanjut dari file existing: {labeled_file}")
    else:
        df_work = df_to_label[required].copy()
        print("Struktur file labeled lama tidak cocok, mulai dari sample terbaru.")
else:
    df_work = df_to_label[base_cols + ['manual_label']].copy()

valid_labels = {'positive', 'negative', 'neutral'}

print("\nMulai labeling manual.")
print("Input yang diterima: positive / negative / neutral")
print("Ketik 'skip' untuk lewati, 'exit' untuk berhenti lebih awal.\n")

for i in range(len(df_work)):
    current = str(df_work.at[i, 'manual_label']).strip().lower()
    if current in valid_labels:
        continue  # sudah terisi valid, lewati

    print("=" * 80)
    print(f"Data ke-{i+1}/{len(df_work)}")
    print(f"cm_cell         : {df_work.at[i, 'cm_cell']}")
    print(f"indobert_label       : {df_work.at[i, 'indobert_label']}")
    print(f"final_sentiment : {df_work.at[i, 'final_sentiment']}")
    print(f"cleaned_text    : {df_work.at[i, 'cleaned_text']}")

    while True:
        user_in = input("manual_label [positive/negative/neutral | skip | exit]: ").strip().lower()
        if user_in in valid_labels:
            df_work.at[i, 'manual_label'] = user_in
            break
        if user_in == 'skip':
            break
        if user_in == 'exit':
            print("Proses dihentikan oleh user.")
            df_work.to_csv(labeled_file, index=False, encoding='utf-8-sig')
            print(f"Progress tersimpan ke: {labeled_file}")
            raise SystemExit
        print("Input tidak valid. Gunakan: positive, negative, neutral, skip, atau exit.")

# Simpan hasil akhir
df_work.to_csv(labeled_file, index=False, encoding='utf-8-sig')
print(f"\nSelesai. Hasil tersimpan ke: {labeled_file}")
print("Kolom output: cm_cell, cleaned_text, indobert_label, final_sentiment, manual_label")

# Preview hasil
df_work.head(10)
# Out:
# File sample tersimpan: error_samples_for_labeling.csv (60 baris)
# Lanjut dari file existing: error_samples_labeled.csv
#
# Mulai labeling manual.
# Input yang diterima: positive / negative / neutral
# Ketik 'skip' untuk lewati, 'exit' untuk berhenti lebih awal.
#
#
# Selesai. Hasil tersimpan ke: error_samples_labeled.csv
# Kolom output: cm_cell, cleaned_text, indobert_label, final_sentiment, manual_label
#                         cm_cell  \
# 0  true=negative | pred=neutral
# 1  true=negative | pred=neutral
# 2  true=negative | pred=neutral
# 3  true=negative | pred=neutral
# 4  true=negative | pred=neutral
# 5  true=negative | pred=neutral
# 6  true=negative | pred=neutral
# 7  true=negative | pred=neutral
# 8  true=negative | pred=neutral
# 9  true=negative | pred=neutral
#
#                                         cleaned_text indobert_label  \
# 0  Harus ada tindakan yg lebih untuk paling tidak...        neutral
# 1  Call me lebay, tp semoga aku tetapi konsisten ...        neutral
# 2                             Boikot aja lah filmnya        neutral
# 3           Kami Masih Konsisten Boikot, Kalau Anda?        neutral
# 4  Dunia Bersatu Melawan Israel? Sanksi, Boikot, ...        neutral
# 5       Statistik terus bertambah. Teruskan boikot !        neutral
# 6  महाकुंभ प्रयागराज प्रयागराज अयोध्या धाम चलो अय...        neutral
# 7  tapi banyak hal yg menguatkan kenapa seharusny...        neutral
# 8     Aneeehhh....tu monyt solo yg hrs nya di boikot        neutral
# 9  2. Dengan boikot, penggemar dapat menunjukkan ...        neutral
#
#   final_sentiment manual_label
# 0        negative     negative
# 1        negative     negative
# 2        negative     negative
# 3        negative     negative
# 4        negative     negative
# 5        negative     negative
# 6        negative      neutral
# 7        negative      neutral
# 8        negative     negative
# 9        negative     negative

# %%
if 'df_work' not in globals():
    raise ValueError("`df_work` belum ada. Jalankan cell labeling terlebih dahulu.")
valid_labels = {'positive', 'negative', 'neutral'}
df_eval = df_work[df_work['manual_label'].isin(valid_labels) & df_work['indobert_label'].isin(valid_labels)].copy()
accuracy = (df_eval['indobert_label'] == df_eval['manual_label']).mean()
print(f"Keakuratan indobert label terhadap manual label: {accuracy:.2%}")
# Out:
# Keakuratan indobert label terhadap manual label: 25.00%

# %%
if 'df_work' not in globals():
    raise ValueError("`df_work` belum ada. Jalankan cell labeling terlebih dahulu.")
valid_labels = {'positive', 'negative', 'neutral'}
df_eval = df_work[df_work['manual_label'].isin(valid_labels) & df_work['final_sentiment'].isin(valid_labels)].copy()
accuracy = (df_eval['final_sentiment'] == df_eval['manual_label']).mean()
print(f"Keakuratan Final Sentiment terhadap manual label: {accuracy:.2%}")
# Out:
# Keakuratan Final Sentiment terhadap manual label: 48.33%
