# %% [markdown]
# # NEW TOTAL DATA VAKSIN

# %%
import pandas as pd

df_gpt = pd.read_csv("vaksin_checkpoint_gpt54_sentiment.csv", low_memory=False)
df_gpt.shape
# Out:
# (10000, 20)

# %%
df_gpt = df_gpt[["cleaned_text", "gpt_label"]].drop_duplicates()
df_gpt.head()
# Out:
#                                         cleaned_text gpt_label
# 0  Keadaan memang benar-benar begitu cepat beruba...  negative
# 1  Klw dada seharian nyesek, parno sendiri antara...  negative
# 2  Kabareskrim: Tindak Tegas Hoaks Penanganan Cov...   neutral
# 3  Penutupan jalan itu bener2 useless, bikin maki...  negative
# 4   Covid gini w mikir punya pacar aja ngga nder :((  negative

# %%
df_new = pd.read_csv("total_data_cleaned_vaksin.csv", low_memory=False)

df_new.shape
# Out:
# (641138, 54)

# %%
df_new = df_new[["cleaned_text", "final_sentiment"]].drop_duplicates()
df_new.head()
# Out:
#                                         cleaned_text final_sentiment
# 0  Kl u/ PTMT....hrs ada sertifikat vaksin krn ke...        positive
# 1  gausa pilih pilih ya pak bu mbak mas, yang waj...        negative
# 2  "Jika benar kita negara gagal, saya tidak rasa...        negative
# 3  Peranan Organisasi keagamaan sangat Penting da...        positive
# 4  Pengalaman saya setelah vaksin itu nyaman sih ...        negative

# %%
# join the two dataframes on the "cleaned_text" column, keep final_sentiment from new dataframe and gpt_label from gpt dataframe
df_joined = pd.merge(
    pd.DataFrame({"cleaned_text": df_gpt["cleaned_text"], "gpt_label": df_gpt["gpt_label"]}),
    pd.DataFrame({"cleaned_text": df_new["cleaned_text"], "final_sentiment": df_new["final_sentiment"]}),
    on="cleaned_text",
    how="inner",
).drop_duplicates()
df_joined.head()
# Out:
#                                         cleaned_text gpt_label final_sentiment
# 0  Keadaan memang benar-benar begitu cepat beruba...  negative        positive
# 1  Klw dada seharian nyesek, parno sendiri antara...  negative        positive
# 2  Kabareskrim: Tindak Tegas Hoaks Penanganan Cov...   neutral        positive
# 3  Penutupan jalan itu bener2 useless, bikin maki...  negative        positive
# 4   Covid gini w mikir punya pacar aja ngga nder :((  negative        negative

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Pakai dataframe hasil join sebagai sampel evaluasi
df_sample = df_joined.copy()
df = df_sample

# Tentukan kolom teks
text_col = None
for candidate in ['cleaned_text', 'full_text', 'text', 'content', 'tweet']:
    if candidate in df_sample.columns:
        text_col = candidate
        break

# 3.5c. Evaluasi semua metode sentimen + Confusion matrices + F1 bar chart

if text_col is not None:
    ref = df_sample['final_sentiment'].astype(str).str.lower()
    _label_norm = {'pro': 'positive', 'pos': 'positive',
                   'contra': 'negative', 'neg': 'negative', 'neu': 'neutral'}
    ref = ref.map(lambda x: _label_norm.get(x, x))
    labels_order = ['negative', 'neutral', 'positive']

    method_cols = {
        'LLM (GPT 5.4 mini)': 'gpt_label',
    }
    predictions = {name: df_sample[col]
                   for name, col in method_cols.items() if col in df_sample.columns}

    missing_methods = [name for name, col in method_cols.items()
                       if col not in df_sample.columns]
    if missing_methods:
        print(f"Metode tidak tersedia (dilewati): {missing_methods}")

    if len(predictions) == 0:
        print("Tidak ada kolom prediksi sentimen. Evaluasi dilewati.")
    else:
        from sklearn.metrics import (accuracy_score, f1_score, precision_score,
                                     recall_score, confusion_matrix)

        eval_rows = []
        conf_matrices = {}
        for name, preds in predictions.items():
            pred = preds.astype(str).str.lower().map(lambda x: _label_norm.get(x, x))
            acc = accuracy_score(ref, pred)
            f1_mac = f1_score(ref, pred, labels=labels_order, average='macro', zero_division=0)
            f1_per = f1_score(ref, pred, labels=labels_order, average=None, zero_division=0)
            prec = precision_score(ref, pred, labels=labels_order, average='macro', zero_division=0)
            rec = recall_score(ref, pred, labels=labels_order, average='macro', zero_division=0)
            cm = confusion_matrix(ref, pred, labels=labels_order)
            eval_rows.append({'Method': name, 'Accuracy': acc, 'Macro-F1': f1_mac,
                              'F1 Neg': f1_per[0], 'F1 Neu': f1_per[1], 'F1 Pos': f1_per[2],
                              'Precision': prec, 'Recall': rec})
            conf_matrices[name] = cm

        df_eval = pd.DataFrame(eval_rows)
        print("=== PERBANDINGAN METODE SENTIMENT ===")
        print(df_eval.to_string(index=False))

        # Confusion matrices
        n_methods = len(conf_matrices)
        ncols = min(3, n_methods)
        nrows = math.ceil(n_methods / ncols)
        fig, axes = plt.subplots(nrows, ncols, figsize=(7 * ncols, 6 * nrows))
        if n_methods == 1:
            axes = np.array([axes])

        for ax, (name, cm) in zip(np.array(axes).flat, conf_matrices.items()):
            sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax,
                        xticklabels=labels_order, yticklabels=labels_order)
            acc_v = accuracy_score(ref, predictions[name].astype(str).str.lower()
                                   .map(lambda x: _label_norm.get(x, x)))
            ax.set_title(f'{name}\nAccuracy={acc_v:.3f}', fontweight='bold')
            ax.set_xlabel('Predicted')
            ax.set_ylabel('True')

        for ax in list(np.array(axes).flat)[len(conf_matrices):]:
            ax.axis('off')

        plt.suptitle('Confusion Matrices - Perbandingan Metode Sentiment',
                     fontweight='bold', fontsize=14, y=1.02)
        plt.tight_layout()
        plt.show()

        # F1 bar chart
        fig, ax = plt.subplots(figsize=(max(10, 4 * len(df_eval)), 5))
        x = np.arange(len(df_eval))
        width = 0.2
        ax.bar(x - 1.5 * width, df_eval['F1 Neg'], width, label='F1 Negative', color='#e74c3c', alpha=0.8)
        ax.bar(x - 0.5 * width, df_eval['F1 Neu'], width, label='F1 Neutral', color='#95a5a6', alpha=0.8)
        ax.bar(x + 0.5 * width, df_eval['F1 Pos'], width, label='F1 Positive', color='#2ecc71', alpha=0.8)
        ax.bar(x + 1.5 * width, df_eval['Macro-F1'], width, label='Macro-F1', color='#3498db', alpha=0.8)
        ax.set_xticks(x)
        ax.set_xticklabels(df_eval['Method'], rotation=20, ha='right')
        ax.set_ylabel('F1 Score')
        ax.set_title('Sentiment Methods - F1 Score Comparison', fontweight='bold')
        ax.legend()
        ax.grid(True, alpha=0.3, axis='y')
        ax.set_ylim(0, 1)
        plt.tight_layout()
        plt.show()
else:
    print("Evaluasi sentimen dilewati (kolom teks tidak ditemukan).")
# Out:
# === PERBANDINGAN METODE SENTIMENT ===
#             Method  Accuracy  Macro-F1   F1 Neg   F1 Neu   F1 Pos  Precision   Recall
# LLM (GPT 5.4 mini)  0.340244  0.281049 0.502201 0.113111 0.227836   0.332588 0.371519

# %%
# Ambil sample 10 data per sel error (off-diagonal) confusion matrix
import pandas as pd

labels_order = ['negative', 'neutral', 'positive']
_label_norm = {
    'pro': 'positive', 'pos': 'positive',
    'contra': 'negative', 'neg': 'negative', 'neu': 'neutral'
}

# Pastikan dataframe sumber ada
if 'df_joined' not in globals():
    raise ValueError("`df_joined` tidak ditemukan. Jalankan cell join dataframe terlebih dahulu.")

# Siapkan dataframe kerja
df_err = df_joined[['cleaned_text', 'gpt_label', 'final_sentiment']].copy()
df_err['gpt_label'] = df_err['gpt_label'].astype(str).str.lower().map(lambda x: _label_norm.get(x, x))
df_err['final_sentiment'] = df_err['final_sentiment'].astype(str).str.lower().map(lambda x: _label_norm.get(x, x))

# Filter hanya label yang valid
df_err = df_err[
    df_err['gpt_label'].isin(labels_order)
    & df_err['final_sentiment'].isin(labels_order)
]

# Ambil 10 sample untuk tiap pasangan true-pred yang salah (6 sel off-diagonal)
samples_per_error_cell = {}
sample_rows = []

for true_label in labels_order:
    for pred_label in labels_order:
        if true_label == pred_label:
            continue  # skip diagonal (prediksi benar)

        key = f"true={true_label} | pred={pred_label}"
        subset = df_err[
            (df_err['final_sentiment'] == true_label)
            & (df_err['gpt_label'] == pred_label)
        ][['cleaned_text', 'gpt_label', 'final_sentiment']]

        n_take = min(10, len(subset))
        sampled = subset.sample(n=n_take, random_state=42) if n_take > 0 else subset.copy()
        samples_per_error_cell[key] = sampled

        if n_take > 0:
            temp = sampled.copy()
            temp['cm_cell'] = key
            sample_rows.append(temp)

# Gabungkan semua sample agar mudah dilihat / diekspor
if sample_rows:
    df_error_samples = pd.concat(sample_rows, ignore_index=True)
    df_error_samples = df_error_samples[['cm_cell', 'cleaned_text', 'gpt_label', 'final_sentiment']]
else:
    df_error_samples = pd.DataFrame(columns=['cm_cell', 'cleaned_text', 'gpt_label', 'final_sentiment'])

print("Jumlah sample per cell error:")
for k, v in samples_per_error_cell.items():
    print(f"- {k}: {len(v)}")

print("\nPreview gabungan sample:")
df_error_samples.head(20)
# Out:
# Jumlah sample per cell error:
# - true=negative | pred=neutral: 10
# - true=negative | pred=positive: 10
# - true=neutral | pred=negative: 10
# - true=neutral | pred=positive: 10
# - true=positive | pred=negative: 10
# - true=positive | pred=neutral: 10
#
# Preview gabungan sample:
#                           cm_cell  \
# 0    true=negative | pred=neutral
# 1    true=negative | pred=neutral
# 2    true=negative | pred=neutral
# 3    true=negative | pred=neutral
# 4    true=negative | pred=neutral
# 5    true=negative | pred=neutral
# 6    true=negative | pred=neutral
# 7    true=negative | pred=neutral
# 8    true=negative | pred=neutral
# 9    true=negative | pred=neutral
# 10  true=negative | pred=positive
# 11  true=negative | pred=positive
# 12  true=negative | pred=positive
# 13  true=negative | pred=positive
# 14  true=negative | pred=positive
# 15  true=negative | pred=positive
# 16  true=negative | pred=positive
# 17  true=negative | pred=positive
# 18  true=negative | pred=positive
# 19  true=negative | pred=positive
#
#                                          cleaned_text gpt_label  \
# 0   Pemerintah Kota Kediri, Jawa Timur, memutuskan...   neutral
# 1   Dalam upaya menekan penyebaran Covid-19, pemer...   neutral
# 2       Gass lah. Kan lagi ppkm, jd online aja gapapa   neutral
# 3   Melalui aplikasi ini, pasien Covid-19 yg melak...   neutral
# 4                     Ppkm di perpanjang tetap prokes   neutral
# 5   ni covid kek nya cewe deh gendernya, soalnya k...   neutral
# 6   pentingin yg lbh urgent..mbut..soal mayat..udh...   neutral
# 7   PPKM pelan pelan kamu mendekat pelan pelan kam...   neutral
# 8   Indonesia butuh banyak tontonan olahraga di tv...   neutral
# 9     Ini lah PPKM dalam aneka level, berbagai varian   neutral
# 10  Positif covid tapi cuman gejala kok. jadi semb...  positive
# 11  Wkwkkwk,, Nino nino... ntar ada yg tersinggung...  positive
# 12  memulai kegiatan positif selama ppkm ini denga...  positive
# 13  Terus aksi dan reaksi untuk terus bantu rakyat...  positive
# 14  Rebahan dapat membantu memutuskan rantai penye...  positive
# 15  RM0. Tiada yang patut terkecuali daripada mend...  positive
# 16  Keluarga Alm. Pak Akidi Tio Serahkan Bantuan 2...  positive
# 17  Loh bagus malahan pamer habis divaksin, biar o...  positive
# 18  Pelaksanaan Shalat Idul Adha dan Penyembelihan...  positive
# 19  Gubernur Jatim berharap, dalam 2 Minggu ini na...  positive
#
#    final_sentiment
# 0         negative
# 1         negative
# 2         negative
# 3         negative
# 4         negative
# 5         negative
# 6         negative
# 7         negative
# 8         negative
# 9         negative
# 10        negative
# 11        negative
# 12        negative
# 13        negative
# 14        negative
# 15        negative
# 16        negative
# 17        negative
# 18        negative
# 19        negative

# %%
# 1) Simpan sample ke file baru + 2) tambah kolom kosong manual_label + 3) labeling interaktif
import os
import pandas as pd

if 'df_error_samples' not in globals():
    raise ValueError("`df_error_samples` belum ada. Jalankan cell sampling error terlebih dahulu.")

base_cols = ['cm_cell', 'cleaned_text', 'gpt_label', 'final_sentiment']
missing_cols = [c for c in base_cols if c not in df_error_samples.columns]
if missing_cols:
    raise ValueError(f"Kolom berikut belum ada di df_error_samples: {missing_cols}")

# File awal untuk proses labeling
samples_file = 'error_samples_for_labeling.csv'
labeled_file = 'error_samples_labeled.csv'

df_to_label = df_error_samples[base_cols].copy()
if 'manual_label' not in df_to_label.columns:
    df_to_label['manual_label'] = ''

# Simpan file sample baru (dengan manual_label kosong)
df_to_label.to_csv(samples_file, index=False, encoding='utf-8-sig')
print(f"File sample tersimpan: {samples_file} ({len(df_to_label)} baris)")

# Jika sudah pernah ada file labeled, lanjutkan dari file itu agar tidak mengulang dari awal
if os.path.exists(labeled_file):
    prev = pd.read_csv(labeled_file, dtype=str).fillna('')
    required = base_cols + ['manual_label']
    if all(c in prev.columns for c in required):
        df_work = prev[required].copy()
        print(f"Lanjut dari file existing: {labeled_file}")
    else:
        df_work = df_to_label[required].copy()
        print("Struktur file labeled lama tidak cocok, mulai dari sample terbaru.")
else:
    df_work = df_to_label[base_cols + ['manual_label']].copy()

valid_labels = {'positive', 'negative', 'neutral'}

print("\nMulai labeling manual.")
print("Input yang diterima: positive / negative / neutral")
print("Ketik 'skip' untuk lewati, 'exit' untuk berhenti lebih awal.\n")

for i in range(len(df_work)):
    current = str(df_work.at[i, 'manual_label']).strip().lower()
    if current in valid_labels:
        continue  # sudah terisi valid, lewati

    print("=" * 80)
    print(f"Data ke-{i+1}/{len(df_work)}")
    print(f"cm_cell         : {df_work.at[i, 'cm_cell']}")
    print(f"gpt_label       : {df_work.at[i, 'gpt_label']}")
    print(f"final_sentiment : {df_work.at[i, 'final_sentiment']}")
    print(f"cleaned_text    : {df_work.at[i, 'cleaned_text']}")

    while True:
        user_in = input("manual_label [positive/negative/neutral | skip | exit]: ").strip().lower()
        if user_in in valid_labels:
            df_work.at[i, 'manual_label'] = user_in
            break
        if user_in == 'skip':
            break
        if user_in == 'exit':
            print("Proses dihentikan oleh user.")
            df_work.to_csv(labeled_file, index=False, encoding='utf-8-sig')
            print(f"Progress tersimpan ke: {labeled_file}")
            raise SystemExit
        print("Input tidak valid. Gunakan: positive, negative, neutral, skip, atau exit.")

# Simpan hasil akhir
df_work.to_csv(labeled_file, index=False, encoding='utf-8-sig')
print(f"\nSelesai. Hasil tersimpan ke: {labeled_file}")
print("Kolom output: cm_cell, cleaned_text, gpt_label, final_sentiment, manual_label")

# Preview hasil
df_work.head(10)
# Out:
# File sample tersimpan: error_samples_for_labeling.csv (60 baris)
#
# Mulai labeling manual.
# Input yang diterima: positive / negative / neutral
# Ketik 'skip' untuk lewati, 'exit' untuk berhenti lebih awal.
#
# ================================================================================
# Data ke-1/60
# cm_cell         : true=negative | pred=neutral
# gpt_label       : neutral
# final_sentiment : negative
# cleaned_text    : Pemerintah Kota Kediri, Jawa Timur, memutuskan tetap menggelar ajang kompetisi tahunan Coin Emas (Competition in English Massive) 2021, kendati saat ini masih pandemi COVID-19.
# Input tidak valid. Gunakan: positive, negative, neutral, skip, atau exit.
# Input tidak valid. Gunakan: positive, negative, neutral, skip, atau exit.
# Input tidak valid. Gunakan: positive, negative, neutral, skip, atau exit.
# ================================================================================
# Data ke-2/60
# cm_cell         : true=negative | pred=neutral
# gpt_label       : neutral
# final_sentiment : negative
# cleaned_text    : Dalam upaya menekan penyebaran Covid-19, pemerintah telah menetapkan masa PPKM Darurat untuk Pulau Jawa dan Pulau Bali pada 3 sampai 20 Juli 2021. Untuk itu, ayo bersama-sama memutus mata rantai Covid-19 dengan mematuhi aturan yang telah ditetapkan pemerintah. .
# ================================================================================
# Data ke-3/60
# cm_cell         : true=negative | pred=neutral
# gpt_label       : neutral
# final_sentiment : negative
# cleaned_text    : Gass lah. Kan lagi ppkm, jd online aja gapapa
# ================================================================================
# Data ke-4/60
# cm_cell         : true=negative | pred=neutral
# gpt_label       : neutral
# final_sentiment : negative
# cleaned_text    : Melalui aplikasi ini, pasien Covid-19 yg melakukan isoman dpt kapan sj berkonsultasi dgn dokter, baik konsultasi utk resep obat hingga membeli obat di Apotek utk kemudian diantarkan ke rumah.
# ================================================================================
# Data ke-5/60
# cm_cell         : true=negative | pred=neutral
# gpt_label       : neutral
# final_sentiment : negative
# cleaned_text    : Ppkm di perpanjang tetap prokes
# ================================================================================
# Data ke-6/60
# cm_cell         : true=negative | pred=neutral
# gpt_label       : neutral
# final_sentiment : negative
# cleaned_text    : ni covid kek nya cewe deh gendernya, soalnya kalo cwo pasti udah ilang dri bulan kemaren
# ================================================================================
# Data ke-7/60
# cm_cell         : true=negative | pred=neutral
# gpt_label       : neutral
# final_sentiment : negative
# cleaned_text    : pentingin yg lbh urgent..mbut..soal mayat..udh psti dimakamkan...lgian ada komandan satpol pp..tgl perintahkan..kgk usah elu yg ngmg khan bs...urusin penanganan covid..itu lbh pntg...ngerti ora mbut. .
# ================================================================================
# Data ke-8/60
# cm_cell         : true=negative | pred=neutral
# gpt_label       : neutral
# final_sentiment : negative
# cleaned_text    : PPKM pelan pelan kamu mendekat pelan pelan kamu menghilang
# ================================================================================
# Data ke-9/60
# cm_cell         : true=negative | pred=neutral
# gpt_label       : neutral
# final_sentiment : negative
# cleaned_text    : Indonesia butuh banyak tontonan olahraga di tv nasional gaksiiii. Apalagi ppkm gini. Tp jangan bola deh, beneran. Soalnya gak ngerti
# ================================================================================
# Data ke-10/60
# cm_cell         : true=negative | pred=neutral
# gpt_label       : neutral
# final_sentiment : negative
# cleaned_text    : Ini lah PPKM dalam aneka level, berbagai varian
# ================================================================================
# Data ke-11/60
# cm_cell         : true=negative | pred=positive
# gpt_label       : positive
# final_sentiment : negative
# cleaned_text    : Positif covid tapi cuman gejala kok. jadi sembuhnya cepet
# ================================================================================
# Data ke-12/60
# cm_cell         : true=negative | pred=positive
# gpt_label       : positive
# final_sentiment : negative
# cleaned_text    : Wkwkkwk,, Nino nino... ntar ada yg tersinggung loh dengan istilah 20 menit, PPKM semoga Ampe 2 Agustus aja, semoga dunia ini kembali sehat, hilangkan virus Corona ya Allah, Aamiin
# ================================================================================
# Data ke-13/60
# cm_cell         : true=negative | pred=positive
# gpt_label       : positive
# final_sentiment : negative
# cleaned_text    : memulai kegiatan positif selama ppkm ini dengan ngelanjutin buku langka yang gua beli setahun lalu
# ================================================================================
# Data ke-14/60
# cm_cell         : true=negative | pred=positive
# gpt_label       : positive
# final_sentiment : negative
# cleaned_text    : Terus aksi dan reaksi untuk terus bantu rakyat ditengah endemi covid Harapan rakyat harapan demokrat
# ================================================================================
# Data ke-15/60
# cm_cell         : true=negative | pred=positive
# gpt_label       : positive
# final_sentiment : negative
# cleaned_text    : Rebahan dapat membantu memutuskan rantai penyebaran Covid-19 ya
# ================================================================================
# Data ke-16/60
# cm_cell         : true=negative | pred=positive
# gpt_label       : positive
# final_sentiment : negative
# cleaned_text    : RM0. Tiada yang patut terkecuali daripada mendapat perlindungan. Jika anda kenal sesiapa yang belum daftar untuk vaksin, bantu mereka mendaftar.
# ================================================================================
# Data ke-17/60
# cm_cell         : true=negative | pred=positive
# gpt_label       : positive
# final_sentiment : negative
# cleaned_text    : Keluarga Alm. Pak Akidi Tio Serahkan Bantuan 2 Triliuan untuk Tangani Covid 19 di Sumsel, 26 Juli 2021 di Polda Sumsel di Palembang Kalo semua keluarga Kaya sumbang kek gini.. Tak susah Jeng Sri pinjam sana pinjam sini... Semoga makin banyak yg terinspirasi, spt
# ================================================================================
# Data ke-18/60
# cm_cell         : true=negative | pred=positive
# gpt_label       : positive
# final_sentiment : negative
# cleaned_text    : Loh bagus malahan pamer habis divaksin, biar orang2 lain yg belum di vaksin, juga bisa ikut2an mau di vaksin.. Hadeuh
# ================================================================================
# Data ke-19/60
# cm_cell         : true=negative | pred=positive
# gpt_label       : positive
# final_sentiment : negative
# cleaned_text    : Pelaksanaan Shalat Idul Adha dan Penyembelihan hewan kurban berjalan dengan aman dan tertib dengan tetap menerapkan protokol kesehatan pencegahan Covid-19.
# ================================================================================
# Data ke-20/60
# cm_cell         : true=negative | pred=positive
# gpt_label       : positive
# final_sentiment : negative
# cleaned_text    : Gubernur Jatim berharap, dalam 2 Minggu ini nantinya bisa segera turun drastis kasus covid-19.
# ================================================================================
# Data ke-21/60
# cm_cell         : true=neutral | pred=negative
# gpt_label       : negative
# final_sentiment : neutral
# cleaned_text    : Kasus Positif COVID-19 di Bantul Bertambah 849 Dalam Sehari
# ================================================================================
# Data ke-22/60
# cm_cell         : true=neutral | pred=negative
# gpt_label       : negative
# final_sentiment : neutral
# cleaned_text    : Apakah Asia Tenggara menjadi episentrum Covid 19 yg selanjutnya? Nauzubillah min zalik
# ================================================================================
# Data ke-23/60
# cm_cell         : true=neutral | pred=negative
# gpt_label       : negative
# final_sentiment : neutral
# cleaned_text    : Pengen diet tapi takut covid.
# ================================================================================
# Data ke-24/60
# cm_cell         : true=neutral | pred=negative
# gpt_label       : negative
# final_sentiment : neutral
# cleaned_text    : I miss going out with my friends.  Ya Allah, Kau murahkanlah rezekiku dan Kau angkatlah musibah covid 19 ini. Ameen!
# ================================================================================
# Data ke-25/60
# cm_cell         : true=neutral | pred=negative
# gpt_label       : negative
# final_sentiment : neutral
# cleaned_text    : PPKM Darurat: Mengkhawatirkan, Pemakaman Jenazah Covid-19 di Jakarta Tembus Rekor
# ================================================================================
# Data ke-26/60
# cm_cell         : true=neutral | pred=negative
# gpt_label       : negative
# final_sentiment : neutral
# cleaned_text    : Huhu tmn segeng smp dia ada yg meninggal.. I can’t take it to see this scenery within 6 months.. Smg penanganan covid disini cepet baik
# ================================================================================
# Data ke-27/60
# cm_cell         : true=neutral | pred=negative
# gpt_label       : negative
# final_sentiment : neutral
# cleaned_text    : Benar2 melukai hati rakyat sendiri yg sdg berjibaku dg covid, dimana hati nurani kalian para penguasa???
# ================================================================================
# Data ke-28/60
# cm_cell         : true=neutral | pred=negative
# gpt_label       : negative
# final_sentiment : neutral
# cleaned_text    : Ini yang gw pikirin pas ibu kritis dan bapak suspect, kebetulan gw kerja diluar kota dan alhamdulilah negatif covid, pas vidcall sama ibu diminta buat jaga adek kalau kenapa2, pusing dah gw mana masih belum mandiri, bener bener nih corona
# ================================================================================
# Data ke-29/60
# cm_cell         : true=neutral | pred=negative
# gpt_label       : negative
# final_sentiment : neutral
# cleaned_text    : Piye jal? Berturut-turut Kasus Harian Positif Covid-19 di Indonesia Pecahkan Rekor Dunia
# ================================================================================
# Data ke-30/60
# cm_cell         : true=neutral | pred=negative
# gpt_label       : negative
# final_sentiment : neutral
# cleaned_text    : UAS Tuding Demi Bisnis Ada RS Riau Rekayasa Pasien Covid
# ================================================================================
# Data ke-31/60
# cm_cell         : true=neutral | pred=positive
# gpt_label       : positive
# final_sentiment : neutral
# cleaned_text    : Luncurkan Gerakan Lawan Covid-19 di Tuban
# ================================================================================
# Data ke-32/60
# cm_cell         : true=neutral | pred=positive
# gpt_label       : positive
# final_sentiment : neutral
# cleaned_text    : Kapoldasu dan Bupati Langkat Tinjau Pelaksanaan Vaksinasi Dosis Kedua, Jubir Covid-19: 35.386 Warga Langkat Sudah Divaksin Dosis Kedua -
# ================================================================================
# Data ke-33/60
# cm_cell         : true=neutral | pred=positive
# gpt_label       : positive
# final_sentiment : neutral
# cleaned_text    : Bagikan Masker, Satgas Covid-19 Kecamatan Bulu memberikan Masker kepada masyarakat guna mencegah Penyebaran Covid-19 di wilayah Kecamatan Bulu. Sabtu, 17/7/21 . .
# ================================================================================
# Data ke-34/60
# cm_cell         : true=neutral | pred=positive
# gpt_label       : positive
# final_sentiment : neutral
# cleaned_text    : Arab Saudi Nyatakan Ibadah Haji Tahun Ini Bebas Covid-19
# ================================================================================
# Data ke-35/60
# cm_cell         : true=neutral | pred=positive
# gpt_label       : positive
# final_sentiment : neutral
# cleaned_text    : Jadikan Kelurahan di Pontianak Pilot Projek Vaksinasi Covid: Kejar Herd Immunity
# ================================================================================
# Data ke-36/60
# cm_cell         : true=neutral | pred=positive
# gpt_label       : positive
# final_sentiment : neutral
# cleaned_text    : Aamiin ya Allaah. Senang sekaligus sedeh bacenye gal. Senang karne pade mao vaksin. Sedeh karne pasti rindu berat
# ================================================================================
# Data ke-37/60
# cm_cell         : true=neutral | pred=positive
# gpt_label       : positive
# final_sentiment : neutral
# cleaned_text    : Partai Berkarya Kubu Muchdi PR Gelar Vaksinasi Di ITC Cipulir – Partai Berkarya kubu Muchdi PR ikut menunjukkan kepedulian dalam mengatasi pandemi Covid-19. Sejak Senin (26/7...
# ================================================================================
# Data ke-38/60
# cm_cell         : true=neutral | pred=positive
# gpt_label       : positive
# final_sentiment : neutral
# cleaned_text    : PPKM kebijakan tepat. Dampak yg diharapkan nyata wujudnya.
# ================================================================================
# Data ke-39/60
# cm_cell         : true=neutral | pred=positive
# gpt_label       : positive
# final_sentiment : neutral
# cleaned_text    : alhamdulillah sudah vaksin
# ================================================================================
# Data ke-40/60
# cm_cell         : true=neutral | pred=positive
# gpt_label       : positive
# final_sentiment : neutral
# cleaned_text    : Vaksinasi COVID-19 secara drive thru di Gowa
# ================================================================================
# Data ke-41/60
# cm_cell         : true=positive | pred=negative
# gpt_label       : negative
# final_sentiment : positive
# cleaned_text    : "Saya memilih kurungan 3 hari, karena bagi saya denda 5 juta sungguh besar. Saya gak bisa bayar, karena pendapatan saya saja gak bisa sampai segitu apalagi masa PPKM." kata Asep Lutfi, Pemilik Kedai Kopi yg Sempat Dipenjara Karena PPKM
# ================================================================================
# Data ke-42/60
# cm_cell         : true=positive | pred=negative
# gpt_label       : negative
# final_sentiment : positive
# cleaned_text    : covid paling, kan gejala e sesek....
# ================================================================================
# Data ke-43/60
# cm_cell         : true=positive | pred=negative
# gpt_label       : negative
# final_sentiment : positive
# cleaned_text    : Ppkm berpengaruhbgt ke penjualan
# ================================================================================
# Data ke-44/60
# cm_cell         : true=positive | pred=negative
# gpt_label       : negative
# final_sentiment : positive
# cleaned_text    : 51 Pegawai KPK Disebut Bakal Diberhentikan Secara Hormat 1 November. PPKM Rakyat Sehat
# ================================================================================
# Data ke-45/60
# cm_cell         : true=positive | pred=negative
# gpt_label       : negative
# final_sentiment : positive
# cleaned_text    : Hubunganku yo wes end game, mugo2 ppkm e nyusul.
# ================================================================================
# Data ke-46/60
# cm_cell         : true=positive | pred=negative
# gpt_label       : negative
# final_sentiment : positive
# cleaned_text    : apa PPKM jamin covid19 berakhir??? msyrkt bkn tdk patuh tp krn punya otak hrs brtanggung jwb pd hdpnya biar tdk mati krn kelaparan.
# ================================================================================
# Data ke-47/60
# cm_cell         : true=positive | pred=negative
# gpt_label       : negative
# final_sentiment : positive
# cleaned_text    : Anies paham situasi apa kedepan kalau covid dianggap main main. Kalau masih setengah hati tunggu 1 bulan lagi ngapain juga DKI. Indonesia bakal kolap
# ================================================================================
# Data ke-48/60
# cm_cell         : true=positive | pred=negative
# gpt_label       : negative
# final_sentiment : positive
# cleaned_text    : Setelah demo kasus covid melonjak ,besok Demo lagi teriak Pemerintah gagal atasi Pandemi.. Tolol kalian
# ================================================================================
# Data ke-49/60
# cm_cell         : true=positive | pred=negative
# gpt_label       : negative
# final_sentiment : positive
# cleaned_text    : Dah covid pkp lgi mmg menganggur laa
# ================================================================================
# Data ke-50/60
# cm_cell         : true=positive | pred=negative
# gpt_label       : negative
# final_sentiment : positive
# cleaned_text    : Covid-19 Bertambah 43.479, Sebanyak 1.893 Jiwa Meninggal
# ================================================================================
# Data ke-51/60
# cm_cell         : true=positive | pred=neutral
# gpt_label       : neutral
# final_sentiment : positive
# cleaned_text    : ppkm kayanya masi sampe 2 agustus yah
# ================================================================================
# Data ke-52/60
# cm_cell         : true=positive | pred=neutral
# gpt_label       : neutral
# final_sentiment : positive
# cleaned_text    : Busetttt, abis vaksin ada rasa lebihh sering cape gaa?
# ================================================================================
# Data ke-53/60
# cm_cell         : true=positive | pred=neutral
# gpt_label       : neutral
# final_sentiment : positive
# cleaned_text    : PPKM FT. Banda niera
# ================================================================================
# Data ke-54/60
# cm_cell         : true=positive | pred=neutral
# gpt_label       : neutral
# final_sentiment : positive
# cleaned_text    : Kocak mo ngelakuin sesuatu pas ppkm gini aja syaratnya banyak bgt wkwk
# ================================================================================
# Data ke-55/60
# cm_cell         : true=positive | pred=neutral
# gpt_label       : neutral
# final_sentiment : positive
# cleaned_text    : gue alumni covid varian lama alias setelah psbb kedua. gejalanya berat sampe nafas pendek sampe capek bgt pcr positif, blm ada antigen, cm indra gue baik2 aja. sekarang varian yg baru sebenernya just flu berat ya menurut gue, cuma bikin pusing bgt nyebarnya cepet bgt
# ================================================================================
# Data ke-56/60
# cm_cell         : true=positive | pred=neutral
# gpt_label       : neutral
# final_sentiment : positive
# cleaned_text    : Temen2 pd terpapar covid, semoga cept membaik
# ================================================================================
# Data ke-57/60
# cm_cell         : true=positive | pred=neutral
# gpt_label       : neutral
# final_sentiment : positive
# cleaned_text    : Pemerintah memperpanjang Pemberlakukan Pembatasan Kegiatan Masyarakat (PPKM) Darurat. Kebijakan tersebut diputuskan disertai pemberian insentif kepada masyarakat dalam bentuk bantuan sosial.
# ================================================================================
# Data ke-58/60
# cm_cell         : true=positive | pred=neutral
# gpt_label       : neutral
# final_sentiment : positive
# cleaned_text    : innalillahi kak.. ijin tanya pas kena covid dan isoman diabetnya terkontrol ga? atau semakin tinggi kadar gulanya? kalau boleh tau selama isoman penanganannya gimana ya dari mulai obat dll, terimakasih
# ================================================================================
# Data ke-59/60
# cm_cell         : true=positive | pred=neutral
# gpt_label       : neutral
# final_sentiment : positive
# cleaned_text    : Turn Back Hoax: [SALAH] Banyaknya Varian Covid-19 Muncul Setelah Vaksinasi Dilakukan
# ================================================================================
# Data ke-60/60
# cm_cell         : true=positive | pred=neutral
# gpt_label       : neutral
# final_sentiment : positive
# cleaned_text    : Mulai skrg ppkm butuh bener bener cari tmpat makan yg lngsung siap.. Klo nunggu masak dulu, keburu hbis waktunya
#
# Selesai. Hasil tersimpan ke: error_samples_labeled.csv
# Kolom output: cm_cell, cleaned_text, gpt_label, final_sentiment, manual_label
#                         cm_cell  \
# 0  true=negative | pred=neutral
# 1  true=negative | pred=neutral
# 2  true=negative | pred=neutral
# 3  true=negative | pred=neutral
# 4  true=negative | pred=neutral
# 5  true=negative | pred=neutral
# 6  true=negative | pred=neutral
# 7  true=negative | pred=neutral
# 8  true=negative | pred=neutral
# 9  true=negative | pred=neutral
#
#                                         cleaned_text gpt_label  \
# 0  Pemerintah Kota Kediri, Jawa Timur, memutuskan...   neutral
# 1  Dalam upaya menekan penyebaran Covid-19, pemer...   neutral
# 2      Gass lah. Kan lagi ppkm, jd online aja gapapa   neutral
# 3  Melalui aplikasi ini, pasien Covid-19 yg melak...   neutral
# 4                    Ppkm di perpanjang tetap prokes   neutral
# 5  ni covid kek nya cewe deh gendernya, soalnya k...   neutral
# 6  pentingin yg lbh urgent..mbut..soal mayat..udh...   neutral
# 7  PPKM pelan pelan kamu mendekat pelan pelan kam...   neutral
# 8  Indonesia butuh banyak tontonan olahraga di tv...   neutral
# 9    Ini lah PPKM dalam aneka level, berbagai varian   neutral
#
#   final_sentiment manual_label
# 0        negative      neutral
# 1        negative      neutral
# 2        negative     positive
# 3        negative     positive
# 4        negative      neutral
# 5        negative      neutral
# 6        negative      neutral
# 7        negative     negative
# 8        negative     negative
# 9        negative      neutral

# %%
# buatlah keakurasian gpt_label terhadap manual_label
if 'df_work' not in globals():
    raise ValueError("`df_work` belum ada. Jalankan cell labeling terlebih dahulu.")
valid_labels = {'positive', 'negative', 'neutral'}
df_eval = df_work[df_work['manual_label'].isin(valid_labels) & df_work['gpt_label'].isin(valid_labels)].copy()
accuracy = (df_eval['gpt_label'] == df_eval['manual_label']).mean()
print(f"Keakuratan GPT label terhadap manual label: {accuracy:.2%}")
# Out:
# Keakuratan GPT label terhadap manual label: 56.67%

# %%
# buatlah keakurasian final_sentiment terhadap manual_label
if 'df_work' not in globals():
    raise ValueError("`df_work` belum ada. Jalankan cell labeling terlebih dahulu.")
valid_labels = {'positive', 'negative', 'neutral'}
df_eval = df_work[df_work['manual_label'].isin(valid_labels) & df_work['final_sentiment'].isin(valid_labels)].copy()
accuracy = (df_eval['final_sentiment'] == df_eval['manual_label']).mean()
print(f"Keakuratan Final Sentiment terhadap manual label: {accuracy:.2%}")
# Out:
# Keakuratan Final Sentiment terhadap manual label: 18.33%
